# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
plt.boxplot(df["Annual Salary"])

# Plot customization

plt.title('Employee Annual Salary Distribution')
plt.ylabel('Annual Salary of Employees')
plt.grid(True)
plt.show()
