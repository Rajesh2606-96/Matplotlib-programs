# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
df2 = (df.head(50))
plt.stem(df2["Age"])
plt.title('Stem Plot of Employee Ages')
plt.ylabel('Age')

plt.show()
